# %% [markdown]
# # Jaeger sample

# %%
# run all code cells of the specified notebook
# %run /notebooks/python3-kernel/libs/jaeger-class.ipynb
# Out:
# Python Version :  3.6.9 (default, Nov  7 2019, 10:44:02)
# [GCC 8.3.0]
# Pandas Version :  0.25.3

# %%
hostname = "192.168.1.5"
port = 16686

jaegerDataFrame = JaegerDataFrame(hostname)
traceDf = jaegerDataFrame.loadTrace("7c1452a231ddf8a6")

traceDf
# Out:
#             traceID            spanID  flags                  operationName  \
# 0  7c1452a231ddf8a6  7c1452a231ddf8a6      1        ResourceController.home
# 1  7c1452a231ddf8a6  c90d78bae7b7d667      1            PrinterUtil.tagDemo
# 2  7c1452a231ddf8a6  bc7dee8bda470f72      1  ChaosGenerator.raiseException
# 3  7c1452a231ddf8a6  503b8db844cbeaee      1            PrinterUtil.logDemo
#
#                                           references         startTime  \
# 0                                                 []  1602998960349000
# 1  [{'refType': 'CHILD_OF', 'traceID': '7c1452a23...  1602998960389000
# 2  [{'refType': 'CHILD_OF', 'traceID': '7c1452a23...  1602998960418000
# 3  [{'refType': 'CHILD_OF', 'traceID': '7c1452a23...  1602998960477000
#
#    duration                                               tags  \
# 0    140698  [{'key': 'internal.span.format', 'type': 'stri...
# 1     86405  [{'key': 'static-tag1', 'type': 'string', 'val...
# ...

# %%
filepath = "/data/jaeger-sample-7c1452a231ddf8a6.json"

df = jaegerDataFrame.loadTraceFromFile(filepath)
df
# Out:
#             traceID            spanID  flags                  operationName  \
# 0  7c1452a231ddf8a6  7c1452a231ddf8a6      1        ResourceController.home
# 1  7c1452a231ddf8a6  c90d78bae7b7d667      1            PrinterUtil.tagDemo
# 2  7c1452a231ddf8a6  bc7dee8bda470f72      1  ChaosGenerator.raiseException
# 3  7c1452a231ddf8a6  503b8db844cbeaee      1            PrinterUtil.logDemo
#
#                                           references         startTime  \
# 0                                                 []  1602998960349000
# 1  [{'refType': 'CHILD_OF', 'traceID': '7c1452a23...  1602998960389000
# 2  [{'refType': 'CHILD_OF', 'traceID': '7c1452a23...  1602998960418000
# 3  [{'refType': 'CHILD_OF', 'traceID': '7c1452a23...  1602998960477000
#
#    duration                                               tags  \
# 0    140698  [{'key': 'internal.span.format', 'type': 'stri...
# 1     86405  [{'key': 'error', 'type': 'bool', 'value': Tru...
# ...
